# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\mithu\OneDrive\Desktop\ann2\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
1+1
# Out:
# 2

# %%
model=load_model('model.h5')
with open('label_encoder_geo.pk1','rb') as file:
    label_encoder_geo=pickle.load(file)
